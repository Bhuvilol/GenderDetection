# %%
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np
import cv2
import os
import cvlib as cv

# %%
model = load_model('gender_detection.keras')
webcam = cv2.VideoCapture(0)
i = 0
while webcam.isOpened():
    status, frame = webcam.read()
    f, confidence = cv.detect_face(frame)
    classes = ['man','woman']
    D = {}
    print(f)
    for i in range(len(f)):
        (startX, startY) = f[i][0], f[i][1]
        (endX, endY) = f[i][2], f[i][3]

        # draw rectangle over face
        cv2.rectangle(frame, (startX,startY), (endX,endY), (0,255,0), 2)
        # crop the detected face region
        face_crop = np.copy(frame[startY:endY,startX:endX])
        face_crop = cv2.resize(face_crop, (96,96))
        face_crop = face_crop.astype("float") / 255.0
        face_crop = img_to_array(face_crop)
        face_crop = np.expand_dims(face_crop, axis=0)
    
        # apply gender detection on face
        conf = model.predict(face_crop)[0] # model.predict return a 2D matrix, ex: [[9.9993384e-01 7.4850512e-05]]

        # get label with max accuracy
        idx = np.argmax(conf)
        label = classes[idx]

        label = "{}: {:.2f}%".format(label, conf[idx] * 100)
        print(label)
        if classes[idx] in D:
            D[classes[idx]] += 1
        else:
            D[classes[idx]] = 1
        print(D)
    cv2.imshow("Gender detection", frame)
        #if cv2.waitKey(1) & 0xFF == ord('q')
    if i == 10:
        break
    
    
    i = 1
webcam.release()
cv2.destroyAllWindows()
# Out:
# [[243, 42, 427, 305]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# man: 86.48%
# {'man': 1}
# [[232, 37, 440, 335]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# man: 96.11%
# {'man': 1}
# [[238, 38, 446, 336]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# man: 97.34%
# {'man': 1}
# [[243, 36, 453, 337]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 96.67%
# {'man': 1}
# [[245, 33, 459, 340]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# man: 97.26%
# {'man': 1}
# [[241, 32, 455, 341]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# man: 97.28%
# {'man': 1}
# [[241, 34, 454, 340]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# man: 97.10%
# {'man': 1}
# [[223, 38, 444, 345]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# man: 98.82%
# {'man': 1}
# [[221, 37, 442, 344]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# man: 97.75%
# {'man': 1}
# [[220, 34, 444, 338]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# man: 97.74%
# {'man': 1}
# [[215, 32, 443, 341]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# man: 96.89%
# {'man': 1}
# [[214, 32, 442, 343]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# man: 97.14%
# {'man': 1}
# [[214, 30, 440, 342]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# man: 96.58%
# {'man': 1}
# [[213, 30, 432, 332]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# man: 95.93%
# {'man': 1}
# [[212, 25, 429, 331]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# man: 96.85%
# {'man': 1}
# [[213, 16, 425, 312]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# man: 97.34%
# {'man': 1}
# [[214, 6, 427, 293]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# man: 98.36%
# {'man': 1}
# [[225, 12, 429, 293]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# man: 96.57%
# {'man': 1}
# [[242, 28, 440, 305]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# man: 96.80%
# {'man': 1}
# [[256, 45, 459, 327]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# man: 93.13%
# {'man': 1}
# [[271, 68, 471, 344]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# man: 84.59%
# {'man': 1}
# [[284, 79, 476, 348]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 76.58%
# {'man': 1}
# [[292, 84, 483, 349]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 63.75%
# {'man': 1}
# [[301, 84, 487, 352]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 19.03%
# {'man': 1}
# [[294, 86, 482, 356]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# man: 24.01%
# {'man': 1}
# [[292, 89, 482, 352]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 19.83%
# {'man': 1}
# [[287, 86, 479, 359]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 25.05%
# {'man': 1}
# [[282, 85, 475, 359]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# man: 22.77%
# {'man': 1}
# [[281, 87, 475, 359]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# man: 15.90%
# {'man': 1}
# [[279, 83, 472, 356]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# man: 29.92%
# {'man': 1}
# [[278, 76, 472, 349]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 50.31%
# {'man': 1}
# [[279, 77, 472, 342]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# man: 52.63%
# {'man': 1}
# [[276, 76, 466, 338]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# man: 52.54%
# {'man': 1}
# [[273, 79, 465, 338]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# man: 66.06%
# {'man': 1}
# [[273, 79, 462, 340]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# man: 63.80%
# {'man': 1}
# [[274, 81, 463, 342]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# man: 59.84%
# {'man': 1}
# [[275, 81, 465, 345]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# man: 48.13%
# {'man': 1}
# [[277, 83, 467, 347]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# man: 56.60%
# {'man': 1}
# [[282, 84, 473, 345]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 43.54%
# {'man': 1}
# [[287, 81, 479, 349]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 45.23%
# {'man': 1}
# [[292, 81, 483, 350]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# man: 32.70%
# {'man': 1}
# [[298, 81, 489, 350]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# man: 29.14%
# {'man': 1}
# [[302, 83, 492, 349]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# woman: 25.07%
# {'woman': 1}
# [[302, 84, 492, 350]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# woman: 27.25%
# {'woman': 1}
# [[301, 85, 491, 352]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 19.84%
# {'woman': 1}
# [[302, 85, 491, 351]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 26.20%
# {'woman': 1}
# [[302, 84, 495, 350]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 36.08%
# {'woman': 1}
# [[306, 79, 502, 350]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# woman: 60.46%
# {'woman': 1}
# [[319, 85, 508, 349]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# woman: 49.54%
# {'woman': 1}
# [[329, 81, 512, 348]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 34.65%
# {'woman': 1}
# [[336, 79, 517, 344]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# woman: 46.38%
# {'woman': 1}
# [[335, 79, 517, 347]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 39.97%
# {'man': 1}
# [[316, 86, 506, 353]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# man: 71.28%
# {'man': 1}
# [[301, 80, 494, 359]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 42.14%
# {'man': 1}
# [[295, 87, 487, 371]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 48.34%
# {'man': 1}
# [[289, 86, 484, 377]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# man: 48.17%
# {'man': 1}
# [[283, 91, 482, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# man: 41.09%
# {'man': 1}
# [[282, 93, 482, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# man: 27.16%
# {'man': 1}
# [[286, 92, 486, 377]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 23.46%
# {'woman': 1}
# [[291, 99, 489, 381]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# woman: 29.90%
# {'woman': 1}
# [[294, 96, 494, 380]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# woman: 67.66%
# {'woman': 1}
# [[298, 96, 495, 381]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# woman: 59.36%
# {'woman': 1}
# [[296, 99, 496, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 60.92%
# {'woman': 1}
# [[296, 101, 496, 383]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# woman: 65.47%
# {'woman': 1}
# [[297, 101, 497, 382]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# woman: 67.21%
# {'woman': 1}
# [[296, 100, 498, 387]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# woman: 64.26%
# {'woman': 1}
# [[297, 101, 498, 385]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# woman: 74.60%
# {'woman': 1}
# [[299, 100, 499, 385]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# woman: 79.88%
# {'woman': 1}
# [[298, 104, 497, 384]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# woman: 69.31%
# {'woman': 1}
# [[297, 102, 497, 386]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# woman: 66.84%
# {'woman': 1}
# [[297, 102, 497, 385]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# woman: 74.30%
# {'woman': 1}
# [[298, 104, 498, 383]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# woman: 65.77%
# {'woman': 1}
# [[297, 102, 498, 383]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# woman: 68.53%
# {'woman': 1}
# [[299, 103, 497, 385]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# woman: 68.31%
# {'woman': 1}
# [[299, 102, 499, 381]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# woman: 71.77%
# {'woman': 1}
# [[299, 104, 498, 383]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# woman: 70.94%
# {'woman': 1}
# [[299, 102, 498, 380]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# woman: 67.66%
# {'woman': 1}
# [[296, 102, 498, 378]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 64.80%
# {'woman': 1}
# [[297, 103, 498, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# woman: 67.83%
# {'woman': 1}
# [[297, 99, 498, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 66.79%
# {'woman': 1}
# [[298, 98, 497, 381]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# woman: 63.85%
# {'woman': 1}
# [[298, 101, 499, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# woman: 59.91%
# {'woman': 1}
# [[300, 100, 500, 378]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# woman: 65.62%
# {'woman': 1}
# [[300, 98, 500, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 76.56%
# {'woman': 1}
# [[301, 101, 499, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 77.48%
# {'woman': 1}
# [[301, 100, 499, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# woman: 70.17%
# {'woman': 1}
# [[301, 99, 500, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# woman: 78.27%
# {'woman': 1}
# [[302, 101, 500, 380]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# woman: 74.61%
# {'woman': 1}
# [[302, 99, 499, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 85.61%
# {'woman': 1}
# [[302, 101, 501, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 81.50%
# {'woman': 1}
# [[302, 103, 500, 378]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 70.63%
# {'woman': 1}
# [[302, 100, 501, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# woman: 78.03%
# {'woman': 1}
# [[302, 101, 500, 380]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 74.21%
# {'woman': 1}
# [[302, 101, 499, 381]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# woman: 66.67%
# {'woman': 1}
# [[302, 101, 500, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# woman: 63.48%
# {'woman': 1}
# [[301, 96, 497, 380]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 69.83%
# {'woman': 1}
# [[300, 97, 496, 378]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 54.20%
# {'woman': 1}
# [[297, 99, 492, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# woman: 24.67%
# {'woman': 1}
# [[292, 97, 491, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# woman: 21.19%
# {'woman': 1}
# [[292, 97, 488, 378]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 18.68%
# {'woman': 1}
# [[291, 95, 488, 377]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# woman: 20.69%
# {'woman': 1}
# [[292, 94, 488, 377]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 24.77%
# {'woman': 1}
# [[292, 94, 489, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# woman: 18.82%
# {'woman': 1}
# [[295, 93, 489, 378]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 27.42%
# {'woman': 1}
# [[297, 92, 491, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# woman: 35.72%
# {'woman': 1}
# [[300, 90, 494, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# woman: 48.52%
# {'woman': 1}
# [[302, 90, 495, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# man: 30.74%
# {'man': 1}
# [[301, 86, 494, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# woman: 40.32%
# {'woman': 1}
# [[301, 86, 494, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# man: 39.88%
# {'man': 1}
# [[301, 86, 493, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# man: 27.53%
# {'man': 1}
# [[301, 89, 494, 368]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# man: 35.03%
# {'man': 1}
# [[300, 89, 490, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# man: 23.72%
# {'man': 1}
# [[299, 90, 488, 371]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# man: 35.78%
# {'man': 1}
# [[297, 90, 488, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# man: 43.67%
# {'man': 1}
# [[295, 93, 488, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# man: 53.28%
# {'man': 1}
# [[295, 92, 487, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# man: 48.51%
# {'man': 1}
# [[296, 91, 487, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# man: 31.11%
# {'man': 1}
# [[296, 90, 486, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# man: 29.04%
# {'man': 1}
# [[296, 88, 487, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# man: 28.57%
# {'man': 1}
# [[297, 92, 488, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 28.90%
# {'man': 1}
# [[298, 93, 490, 367]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# woman: 33.38%
# {'woman': 1}
# [[300, 92, 493, 369]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 27.92%
# {'man': 1}
# [[301, 93, 496, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# man: 36.55%
# {'man': 1}
# [[301, 93, 494, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 28.78%
# {'man': 1}
# [[301, 89, 491, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# man: 40.28%
# {'man': 1}
# [[301, 92, 491, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 33.04%
# {'man': 1}
# [[301, 93, 490, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 18.96%
# {'man': 1}
# [[300, 94, 491, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# man: 39.18%
# {'man': 1}
# [[301, 95, 490, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# man: 21.57%
# {'man': 1}
# [[301, 97, 489, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 24.81%
# {'man': 1}
# [[300, 98, 489, 378]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 30.54%
# {'man': 1}
# [[301, 96, 490, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 17.62%
# {'woman': 1}
# [[301, 95, 491, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# woman: 20.60%
# {'woman': 1}
# [[302, 98, 491, 379]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# man: 35.32%
# {'man': 1}
# [[302, 96, 491, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# woman: 24.29%
# {'woman': 1}
# [[302, 97, 496, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# woman: 35.93%
# {'woman': 1}
# [[303, 94, 497, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# woman: 31.22%
# {'woman': 1}
# [[304, 89, 499, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# woman: 41.06%
# {'woman': 1}
# [[304, 93, 500, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# woman: 35.03%
# {'woman': 1}
# [[306, 93, 504, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# woman: 40.50%
# {'woman': 1}
# [[309, 94, 506, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 48.66%
# {'woman': 1}
# [[309, 95, 505, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 37.98%
# {'woman': 1}
# [[309, 94, 505, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# woman: 33.68%
# {'woman': 1}
# [[309, 95, 506, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 30.18%
# {'woman': 1}
# [[310, 93, 506, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 53.27%
# {'woman': 1}
# [[308, 96, 505, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# woman: 40.23%
# {'woman': 1}
# [[308, 93, 505, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 39.12%
# {'woman': 1}
# [[309, 92, 505, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 49.08%
# {'woman': 1}
# [[308, 91, 505, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 34.09%
# {'woman': 1}
# [[309, 91, 505, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 44.24%
# {'woman': 1}
# [[309, 93, 505, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# woman: 50.17%
# {'woman': 1}
# [[309, 91, 505, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# woman: 50.35%
# {'woman': 1}
# [[310, 93, 506, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 55.35%
# {'woman': 1}
# [[309, 90, 505, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# woman: 47.84%
# {'woman': 1}
# [[308, 91, 504, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 60.55%
# {'woman': 1}
# [[307, 92, 504, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 41.29%
# {'woman': 1}
# [[306, 92, 503, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 51.45%
# {'woman': 1}
# [[307, 92, 503, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# woman: 59.44%
# {'woman': 1}
# [[307, 91, 503, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 38.06%
# {'woman': 1}
# [[307, 89, 503, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# woman: 59.21%
# {'woman': 1}
# [[306, 90, 503, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 35.21%
# {'woman': 1}
# [[307, 86, 504, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 56.52%
# {'woman': 1}
# [[307, 92, 503, 377]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# woman: 36.24%
# {'woman': 1}
# [[307, 89, 504, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# woman: 34.92%
# {'woman': 1}
# [[309, 90, 505, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# woman: 42.85%
# {'woman': 1}
# [[309, 87, 506, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 43.63%
# {'woman': 1}
# [[310, 92, 506, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 40.46%
# {'woman': 1}
# [[309, 90, 505, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# woman: 34.62%
# {'woman': 1}
# [[309, 90, 506, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 48.55%
# {'woman': 1}
# [[309, 92, 507, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# woman: 45.20%
# {'woman': 1}
# [[309, 91, 508, 370]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 36.00%
# {'woman': 1}
# [[313, 96, 508, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# woman: 40.95%
# {'woman': 1}
# [[315, 96, 510, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# woman: 39.81%
# {'woman': 1}
# [[314, 96, 511, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 46.38%
# {'woman': 1}
# [[316, 96, 511, 375]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# woman: 40.47%
# {'woman': 1}
# [[316, 97, 512, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# woman: 37.21%
# {'woman': 1}
# [[316, 97, 512, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 50.27%
# {'woman': 1}
# [[316, 98, 513, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# woman: 39.95%
# {'woman': 1}
# [[317, 96, 512, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# woman: 44.85%
# {'woman': 1}
# [[316, 96, 512, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# woman: 47.37%
# {'woman': 1}
# [[316, 97, 511, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# woman: 40.84%
# {'woman': 1}
# [[315, 97, 512, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# woman: 41.63%
# {'woman': 1}
# [[315, 96, 510, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# woman: 49.71%
# {'woman': 1}
# [[314, 95, 511, 371]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# woman: 41.44%
# {'woman': 1}
# [[317, 96, 510, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# woman: 51.93%
# {'woman': 1}
# [[318, 97, 510, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# woman: 43.50%
# {'woman': 1}
# [[317, 95, 511, 373]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# woman: 47.12%
# {'woman': 1}
# [[317, 97, 510, 372]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# woman: 31.84%
# {'woman': 1}
# [[318, 98, 510, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# woman: 41.20%
# {'woman': 1}
# [[319, 99, 512, 374]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# woman: 47.89%
# {'woman': 1}
# [[317, 96, 513, 376]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# woman: 47.25%
# {'woman': 1}
# [[318, 98, 512, 377]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 24
#      21 face_crop = np.expand_dims(face_crop, axis=0)
#      23 # apply gender detection on face
# ---> 24 conf = model.predict(face_crop)[0] # model.predict return a 2D matrix, ex: [[9.9993384e-01 7.4850512e-05]]
#      26 # get label with max accuracy
#      27 idx = np.argmax(conf)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:442, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     437 @traceback_utils.filter_traceback
#     438 def predict(
#     439     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     440 ):
#     441     # Create an iterator that yields batches of input data.
# --> 442     epoch_iterator = TFEpochIterator(
#     443         x=x,
#     444         batch_size=batch_size,
#     445         steps_per_epoch=steps,
#     446         shuffle=False,
#     447         distribute_strategy=self.distribute_strategy,
#     448         steps_per_execution=self.steps_per_execution,
#     449     )
#     451     # Container that configures and calls callbacks.
#     452     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:625, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     623 super().__init__(*args, **kwargs)
#     624 self._distribute_strategy = distribute_strategy
# --> 625 dataset = self._get_iterator()
#     626 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     627     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     628         dataset
#     629     )
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:634, in TFEpochIterator._get_iterator(self)
#     633 def _get_iterator(self):
# --> 634     return self.data_adapter.get_tf_dataset()
#
# File ~\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:232, in ArrayDataAdapter.get_tf_dataset(self)
#     229     dataset = dataset.with_options(options)
#     230     return dataset
# --> 232 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2344, in DatasetV2.flat_map(self, map_func, name)
#    2340 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2341 # dataset_ops).
#    2342 # pylint: disable=g-import-not-at-top,protected-access
#    2343 from tensorflow.python.data.ops import flat_map_op
# -> 2344 return flat_map_op._flat_map(self, map_func, name=name)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\flat_map_op.py:42, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      40 self._structure = self._map_func.output_structure._element_spec
#      41 self._name = name
# ---> 42 variant_tensor = gen_dataset_ops.flat_map_dataset(
#      43     input_dataset._variant_tensor,  # pylint: disable=protected-access
#      44     self._map_func.function.captured_inputs,
#      45     f=self._map_func.function,
#      46     **self._common_args)
#      47 super().__init__(input_dataset, variant_tensor)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:2426, in flat_map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, metadata, name)
#    2424 if tld.is_eager:
#    2425   try:
# -> 2426     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2427       _ctx, "FlatMapDataset", name, input_dataset, other_arguments, "f", f,
#    2428       "output_types", output_types, "output_shapes", output_shapes,
#    2429       "metadata", metadata)
#    2430     return _result
#    2431   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
webcam.release()
cv2.destroyAllWindows()
